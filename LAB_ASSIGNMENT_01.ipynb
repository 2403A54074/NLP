# %% [markdown]
# <a href="https://colab.research.google.com/github/2403A54074/NLP/blob/main/LAB_ASSIGNMENT_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install nltk spacy

# %%
import nltk
import spacy
text = """
Natural Language Processing enables computers to understand,
interpret, and generate human language. It plays a vital role
in modern artificial intelligence systems.
"""
print("\nNumber of words in the text:", word_count)
lower_text = text.lower()
print("Lowercase Text:\n", lower_text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-940334276.py in <cell line: 0>()
#       6 in modern artificial intelligence systems.
#       7 """
# ----> 8 print("\nNumber of words in the text:", word_count)
#       9 lower_text = text.lower()
#      10 print("Lowercase Text:\n", lower_text)
#
# NameError: name 'word_count' is not defined
